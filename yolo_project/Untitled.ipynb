# %%
from ultralytics import YOLO

# Load a pre-trained model
model = YOLO('yolov8n.pt')  # 'n' is the nano version, fast and lightweight

# Train the model
model.train(data='data.yaml', epochs=30, imgsz=640, batch=8)
# Out:
# Ultralytics 8.3.104  Python-3.12.4 torch-2.6.0+cpu CPU (Intel Core(TM) i5-1035G1 1.00GHz)
# ...

# %%
# Load the trained model
model = YOLO('runs/detect/train/weights/best.pt')

# Test on a sample image
results = model.predict(source='test/images/sample.jpg', save=True, conf=0.4)
